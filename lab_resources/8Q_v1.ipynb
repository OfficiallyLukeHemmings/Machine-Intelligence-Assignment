# %%
from __future__ import print_function, division
import numpy as np
from random import Random, random

# %%
class State(object):
    MUTATION_RATE = 0.4 # Play with this value, higher value means more chance of mutation
    def __init__(self, parents=None, generation = 1):
        r = Random()
        self._fitness = None
        self._probability = None
        self.generation = generation
        if parents==None:
            self.parents = None
            self.state = [r.randint(1,8) for y in range(8)]
            # The following should also work
            #self.state = list(np.random.permutation(8) + 1)
        else:            
            parent1 = parents[0]
            parent2 = parents[1]
            self.parents = parents
            self.state = self.crossover(parent1, parent2)
            self.mutate()

    def fitness(self):                                                                                  
        if not self._fitness:
            state = self.state
            horizontal_collisions = sum([state.count(col)-1 for col in state])/2

            diagonal_collisions = 0
            for i, col in enumerate(state):
                for j, diagonal in enumerate(state):
                    mod = abs(i-j)
                    if mod > 0: #we don't want to count the current queen in a collision with herself
                        if diagonal + mod == col or diagonal - mod == col:
                            diagonal_collisions += 1
            diagonal_collisions /= 2 #we were counting the diagonal collisions double
            self._fitness = int(28 - (horizontal_collisions + diagonal_collisions))
        return self._fitness

    def probability(self, population):
        if not self._probability:
            self._probability = self.fitness() / sum([x.fitness() for x in population])
        return self._probability

    def crossover(self, parent1, parent2):
        r = Random()
        crossover_index = r.randint(0,8)
        left = parent1.state[0:crossover_index]
        right = parent2.state[crossover_index:8]
        left.extend(right)
        return left

    def mutate(self):
        r = Random()
        for i in range(len(self.state)):
            if random() < State.MUTATION_RATE:
                self.state[i] = r.randint(1,8)

    def __str__(self):
        # return repr(self.state)

        queen_symbol = '♛'
        blank_white_symbol = '▧'  # ▧, ▨, ▩, ▥, ▤, ▣
        blank_black_symbol = '☐'

        # _state = np.zeros((8,8), dtype = np.uint8)
        # Create a blank board with alternating 0 and 1
        _i = np.sum(np.indices((8,8)), axis = 0)
        _state = np.where(_i % 2 == 0, 0, 1)
      
        for i, j in enumerate(self.state):
            _state[j - 1, i] = 2

        _repr = "Generation: " + str(self.generation) + "\nFitness: " + str(self.fitness()) + "\n" + str(self.state) +  "\n"
        for h in range(8):
            for w in range(8):
                _repr += ([blank_white_symbol, blank_black_symbol, queen_symbol][_state[h, w]] + " ")
            _repr += "\n"
        return _repr

def pickRandomByProbability(populationByProbability):
    i = 0
    selectedState = None
    while selectedState == None:
        current = populationByProbability[i]
        if current[0] <= random():
            return current[1]
        if i+1 <= len(populationByProbability):
            i = 0
        else:
            i += 1

def generateNextPopulation(population, n):
    newPopulation = []
    while len(newPopulation) < n:
        populationByProbability = [(x.probability(population), x) for x in population]
        parent1 = pickRandomByProbability(populationByProbability)
        populationByProbability = [x for x in populationByProbability if x[1] != parent1]
        parent2 = pickRandomByProbability(populationByProbability)
        newPopulation.append(State((parent1, parent2), generation = parent1.generation + 1))
    return newPopulation


def main():
    populationSize = 100
    generation = 1
    population = [State(generation = generation) for x in range(populationSize)]
    
    while not 28 in [x.fitness() for x in population]:# and generation<100 :
        print("generation %d Max fitness: %d" % (generation, max([x.fitness() for x in population])))
        population = generateNextPopulation(population, populationSize)
        generation += 1

    for x in population:
        if x.fitness() == 28:            
            if x.parents is not None:
                print("Parents::")
                print(x.parents[0])
                print(x.parents[1])
            print("Solution state: ")
            print(x)


if __name__ == '__main__':
    main()
# Out:
# generation 1 Max fitness: 25
# generation 2 Max fitness: 25
# generation 3 Max fitness: 25
# generation 4 Max fitness: 25
# generation 5 Max fitness: 23
# generation 6 Max fitness: 24
# generation 7 Max fitness: 25
# generation 8 Max fitness: 25
# generation 9 Max fitness: 24
# generation 10 Max fitness: 25
# generation 11 Max fitness: 24
# generation 12 Max fitness: 23
# generation 13 Max fitness: 24
# generation 14 Max fitness: 26
# generation 15 Max fitness: 24
# generation 16 Max fitness: 25
# generation 17 Max fitness: 24
# generation 18 Max fitness: 26
# generation 19 Max fitness: 25
# generation 20 Max fitness: 26
# generation 21 Max fitness: 25
# generation 22 Max fitness: 25
# generation 23 Max fitness: 26
# generation 24 Max fitness: 25
# generation 25 Max fitness: 26
# generation 26 Max fitness: 25
# generation 27 Max fitness: 25
# generation 28 Max fitness: 25
# generation 29 Max fitness: 24
# generation 30 Max fitness: 24
# generation 31 Max fitness: 24
# generation 32 Max fitness: 25
# generation 33 Max fitness: 24
# generation 34 Max fitness: 25
# generation 35 Max fitness: 25
# generation 36 Max fitness: 25
# generation 37 Max fitness: 24
# generation 38 Max fitness: 26
# generation 39 Max fitness: 25
# generation 40 Max fitness: 25
# generation 41 Max fitness: 26
# generation 42 Max fitness: 25
# generation 43 Max fitness: 25
# generation 44 Max fitness: 24
# generation 45 Max fitness: 24
# generation 46 Max fitness: 24
# generation 47 Max fitness: 25
# generation 48 Max fitness: 25
# generation 49 Max fitness: 25
# generation 50 Max fitness: 26
# generation 51 Max fitness: 25
# generation 52 Max fitness: 27
# generation 53 Max fitness: 24
# generation 54 Max fitness: 26
# generation 55 Max fitness: 24
# generation 56 Max fitness: 25
# generation 57 Max fitness: 25
# generation 58 Max fitness: 25
# generation 59 Max fitness: 25
# generation 60 Max fitness: 25
# generation 61 Max fitness: 25
# generation 62 Max fitness: 25
# generation 63 Max fitness: 25
# generation 64 Max fitness: 25
# generation 65 Max fitness: 26
# generation 66 Max fitness: 25
# generation 67 Max fitness: 25
# generation 68 Max fitness: 24
# generation 69 Max fitness: 25
# generation 70 Max fitness: 25
# generation 71 Max fitness: 25
# generation 72 Max fitness: 25
# generation 73 Max fitness: 26
# generation 74 Max fitness: 25
# generation 75 Max fitness: 25
# generation 76 Max fitness: 26
# generation 77 Max fitness: 24
# generation 78 Max fitness: 25
# generation 79 Max fitness: 25
# generation 80 Max fitness: 26
# generation 81 Max fitness: 27
# generation 82 Max fitness: 26
# generation 83 Max fitness: 26
# generation 84 Max fitness: 24
# generation 85 Max fitness: 26
# generation 86 Max fitness: 25
# generation 87 Max fitness: 24
# generation 88 Max fitness: 25
# generation 89 Max fitness: 24
# generation 90 Max fitness: 24
# generation 91 Max fitness: 24
# generation 92 Max fitness: 25
# generation 93 Max fitness: 24
# generation 94 Max fitness: 24
# generation 95 Max fitness: 26
# generation 96 Max fitness: 24
# generation 97 Max fitness: 25
# generation 98 Max fitness: 25
# generation 99 Max fitness: 25
# generation 100 Max fitness: 26
# generation 101 Max fitness: 25
# generation 102 Max fitness: 24
# generation 103 Max fitness: 24
# generation 104 Max fitness: 25
# generation 105 Max fitness: 25
# generation 106 Max fitness: 23
# generation 107 Max fitness: 24
# generation 108 Max fitness: 25
# generation 109 Max fitness: 25
# generation 110 Max fitness: 25
# generation 111 Max fitness: 24
# generation 112 Max fitness: 24
# generation 113 Max fitness: 25
# generation 114 Max fitness: 24
# generation 115 Max fitness: 25
# generation 116 Max fitness: 26
# generation 117 Max fitness: 24
# generation 118 Max fitness: 24
# generation 119 Max fitness: 23
# generation 120 Max fitness: 25
# generation 121 Max fitness: 25
# generation 122 Max fitness: 25
# generation 123 Max fitness: 25
# generation 124 Max fitness: 25
# generation 125 Max fitness: 25
# generation 126 Max fitness: 25
# generation 127 Max fitness: 25
# generation 128 Max fitness: 24
# generation 129 Max fitness: 26
# generation 130 Max fitness: 24
# generation 131 Max fitness: 24
# generation 132 Max fitness: 27
# generation 133 Max fitness: 26
# generation 134 Max fitness: 25
# generation 135 Max fitness: 25
# generation 136 Max fitness: 24
# generation 137 Max fitness: 25
# generation 138 Max fitness: 24
# generation 139 Max fitness: 24
# generation 140 Max fitness: 25
# generation 141 Max fitness: 25
# generation 142 Max fitness: 25
# generation 143 Max fitness: 24
# generation 144 Max fitness: 25
# generation 145 Max fitness: 25
# generation 146 Max fitness: 25
# generation 147 Max fitness: 25
# generation 148 Max fitness: 24
# generation 149 Max fitness: 24
# generation 150 Max fitness: 24
# generation 151 Max fitness: 25
# generation 152 Max fitness: 25
# generation 153 Max fitness: 25
# generation 154 Max fitness: 24
# generation 155 Max fitness: 25
# generation 156 Max fitness: 26
# generation 157 Max fitness: 25
# generation 158 Max fitness: 25
# generation 159 Max fitness: 25
# generation 160 Max fitness: 24
# generation 161 Max fitness: 25
# generation 162 Max fitness: 26
# generation 163 Max fitness: 25
# generation 164 Max fitness: 24
# generation 165 Max fitness: 24
# generation 166 Max fitness: 24
# generation 167 Max fitness: 25
# generation 168 Max fitness: 25
# generation 169 Max fitness: 26
# generation 170 Max fitness: 25
# generation 171 Max fitness: 26
# generation 172 Max fitness: 26
# generation 173 Max fitness: 25
# generation 174 Max fitness: 25
# generation 175 Max fitness: 24
# generation 176 Max fitness: 26
# generation 177 Max fitness: 24
# generation 178 Max fitness: 25
# generation 179 Max fitness: 24
# generation 180 Max fitness: 24
# generation 181 Max fitness: 24
# generation 182 Max fitness: 24
# generation 183 Max fitness: 24
# generation 184 Max fitness: 24
# generation 185 Max fitness: 25
# generation 186 Max fitness: 25
# generation 187 Max fitness: 25
# generation 188 Max fitness: 24
# generation 189 Max fitness: 24
# generation 190 Max fitness: 26
# generation 191 Max fitness: 25
# generation 192 Max fitness: 25
# generation 193 Max fitness: 24
# generation 194 Max fitness: 25
# generation 195 Max fitness: 24
# generation 196 Max fitness: 26
# generation 197 Max fitness: 25
# generation 198 Max fitness: 25
# generation 199 Max fitness: 25
# generation 200 Max fitness: 26
# generation 201 Max fitness: 25
# generation 202 Max fitness: 25
# generation 203 Max fitness: 25
# generation 204 Max fitness: 25
# generation 205 Max fitness: 26
# generation 206 Max fitness: 25
# generation 207 Max fitness: 26
# generation 208 Max fitness: 25
# generation 209 Max fitness: 25
# generation 210 Max fitness: 25
# generation 211 Max fitness: 25
# generation 212 Max fitness: 26
# generation 213 Max fitness: 24
# generation 214 Max fitness: 24
# generation 215 Max fitness: 25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2ce5fff69400> in <module>
#     119
#     120 if __name__ == '__main__':
# --> 121     main()
#
# <ipython-input-2-2ce5fff69400> in main()
#     105     while not 28 in [x.fitness() for x in population]:# and generation<100 :
#     106         print("generation %d Max fitness: %d" % (generation, max([x.fitness() for x in population])))
# --> 107         population = generateNextPopulation(population, populationSize)
#     108         generation += 1
#     109
#
# <ipython-input-2-2ce5fff69400> in generateNextPopulation(population, n)
#      94         populationByProbability = [x for x in populationByProbability if x[1] != parent1]
#      95         parent2 = pickRandomByProbability(populationByProbability)
# ---> 96         newPopulation.append(State((parent1, parent2), generation = parent1.generation + 1))
#      97     return newPopulation
#      98
#
# <ipython-input-2-2ce5fff69400> in __init__(self, parents, generation)
#      15             parent2 = parents[1]
#      16             self.parents = parents
# ---> 17             self.state = self.crossover(parent1, parent2)
#      18             self.mutate()
#      19
#
# <ipython-input-2-2ce5fff69400> in crossover(self, parent1, parent2)
#      40
#      41     def crossover(self, parent1, parent2):
# ---> 42         r = Random()
#      43         crossover_index = r.randint(0,8)
#      44         left = parent1.state[0:crossover_index]
#
# ~/opt/anaconda3/lib/python3.7/random.py in __init__(self, x)
#      86     VERSION = 3     # used by getstate/setstate
#      87
# ---> 88     def __init__(self, x=None):
#      89         """Initialize an instance.
#      90
#
# KeyboardInterrupt:
