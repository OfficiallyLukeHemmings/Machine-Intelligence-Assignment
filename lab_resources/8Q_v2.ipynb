# %%
from __future__ import print_function, division
import numpy as np
from random import Random, random
import time

class State(object):
    MUTATION_RATE = 0.08 # Play with this value, higher value means more chance of mutation
    def __init__(self, parents=None, generation = 1):
        r = Random()
        self._fitness = None
        self._probability = None
        self.generation = generation
        if parents==None:
            self.parents = None
            #self.state = [r.randint(1,8) for y in range(8)]
            # The following should also work
            #self.state = list(np.random.permutation(8) + 1)
            
            nrow, ncol = 1, 8
            uarray= (np.random.permutation(nrow * ncol) + 1)
            self.state=uarray.tolist()
            
        else:            
            parent1 = parents[0]
            parent2 = parents[1]
            self.parents = parents
            self.state = self.crossover(parent1, parent2)
            self.mutate()

    def fitness(self): 
        if not self._fitness:
            state = self.state
            
            horizontal_collisions = sum([state.count(col)-1 for col in state])/2
    
            diagonal_collisions = 0
            for i, col in enumerate(state):
                for j, diagonal in enumerate(state):
                    mod = abs(i-j)
                    if mod > 0: #we don't want to count the current queen in a collision with herself
                        if diagonal + mod == col or diagonal - mod == col:
                            diagonal_collisions += 1
            diagonal_collisions /= 2 #we were counting the diagonal collisions double
            self._fitness = int(28 - (horizontal_collisions + diagonal_collisions))
        return self._fitness

    def probability(self, population):
        if not self._probability:
            self._probability = self.fitness() / sum([x.fitness() for x in population])
        return self._probability

    def crossover_naive(self, parent1, parent2):
        r = Random()
        crossover_index = r.randint(0,8)
        left = parent1.state[0:crossover_index]
        right = parent2.state[crossover_index:8]
        left.extend(right)
        return left

    def crossover(self, parent1, parent2):
        r = Random()
        crossover_index = r.randint(0,8)
        left = parent1.state[0:crossover_index]
        
        right = parent2.state[crossover_index:8]
        right.extend(parent2.state[0:crossover_index])
        right.extend(parent1.state[crossover_index:8])
        
        j=len(left)
        k=0
        t=0
        while j<len(parent1.state):
            
            if k<len(right):
            
                if not (right[k] in left):
                        left.append(right[k])
                        j+=1
                k+=1        
            else : 
                a=len(parent1.state)-j
                pos=len(right)-(8-crossover_index)-(crossover_index)+1
                left.extend(right[pos:pos+a])
                j=len(parent1.state)
                
        return left
    
    def mutate_naive(self):
        r = Random()
        for i in range(len(self.state)):
            if random() < State.MUTATION_RATE:
                self.state[i] = r.randint(0,8)
    
    def mutate(self):
        k=0
        i=0
        pos=[]
        while (i < len(self.state)) and (k<=1):
            if random() < State.MUTATION_RATE:
                pos.append(i)
                k+=1
            i+=1
        if k==2:        
            ind1=pos[0]
            ind2=pos[1]
            temp=self.state[ind1]
            self.state[ind1]= self.state[ind2]
            self.state[ind2]=temp
            
    def __str__(self):
        # return repr(self.state)

        queen_symbol = '♛'
        blank_white_symbol = '▧'  # ▧, ▨, ▩, ▥, ▤, ▣
        blank_black_symbol = '☐'

        # _state = np.zeros((8,8), dtype = np.uint8)
        # Create a blank board with alternating 0 and 1
        _i = np.sum(np.indices((8,8)), axis = 0)
        _state = np.where(_i % 2 == 0, 0, 1)
      
        for i, j in enumerate(self.state):
            _state[j - 1, i] = 2

        _repr = "Generation: " + str(self.generation) + "\nFitness: " + str(self.fitness()) + "\n" + str(self.state) +  "\n"
        for h in range(8):
            for w in range(8):
                _repr += ([blank_white_symbol, blank_black_symbol, queen_symbol][_state[h, w]] + " ")
            _repr += "\n"
        return _repr

def pickRandomByProbability(populationByProbability):
    i = 0
    selectedState = None
    while selectedState == None:
        current = populationByProbability[i]
        if current[0] <= random():
            return current[1]
        if i+1 <= len(populationByProbability):
            i = 0
        else:
            i += 1

def generateNextPopulation(population, n):
    newPopulation = []
    while len(newPopulation) < n:
        populationByProbability = [(x.probability(population), x) for x in population]
        parent1 = pickRandomByProbability(populationByProbability)
        populationByProbability = [x for x in populationByProbability if x[1] != parent1]
        parent2 = pickRandomByProbability(populationByProbability)
        newPopulation.append(State((parent1, parent2), generation = parent1.generation + 1))
    return newPopulation



if __name__ == '__main__':
    populationSize = 50
    generation = 0
    population = [State(generation = generation) for x in range(populationSize)]
    
    while not 28 in [x.fitness() for x in population]:
        print("generation %d Max fitness: %d" % (generation, max([x.fitness() for x in population])))
        population = generateNextPopulation(population, populationSize)
        generation += 1

    for x in population:
        if x.fitness() == 28:            
            if x.parents is not None:
                print("Parents::")
                print(x.parents[0])
                print(x.parents[1])
            print("Solution state: ")
            print(x)
# Out:
# generation 0 Max fitness: 27
# generation 1 Max fitness: 27
# generation 2 Max fitness: 27
# generation 3 Max fitness: 23
# generation 4 Max fitness: 25
# generation 5 Max fitness: 25
# generation 6 Max fitness: 24
# generation 7 Max fitness: 27
# generation 8 Max fitness: 26
# generation 9 Max fitness: 25
# generation 10 Max fitness: 25
# generation 11 Max fitness: 25
# generation 12 Max fitness: 23
# generation 13 Max fitness: 23
# generation 14 Max fitness: 22
# generation 15 Max fitness: 23
# generation 16 Max fitness: 22
# generation 17 Max fitness: 23
# generation 18 Max fitness: 22
# generation 19 Max fitness: 23
# generation 20 Max fitness: 23
# generation 21 Max fitness: 23
# generation 22 Max fitness: 23
# generation 23 Max fitness: 22
# generation 24 Max fitness: 23
# generation 25 Max fitness: 23
# generation 26 Max fitness: 23
# generation 27 Max fitness: 22
# generation 28 Max fitness: 24
# generation 29 Max fitness: 23
# generation 30 Max fitness: 23
# generation 31 Max fitness: 24
# generation 32 Max fitness: 25
# generation 33 Max fitness: 25
# generation 34 Max fitness: 23
# generation 35 Max fitness: 25
# generation 36 Max fitness: 23
# generation 37 Max fitness: 24
# generation 38 Max fitness: 26
# generation 39 Max fitness: 23
# generation 40 Max fitness: 26
# generation 41 Max fitness: 25
# generation 42 Max fitness: 25
# generation 43 Max fitness: 25
# generation 44 Max fitness: 24
# generation 45 Max fitness: 26
# generation 46 Max fitness: 25
# generation 47 Max fitness: 26
# generation 48 Max fitness: 26
# generation 49 Max fitness: 26
# generation 50 Max fitness: 26
# generation 51 Max fitness: 25
# generation 52 Max fitness: 23
# generation 53 Max fitness: 25
# generation 54 Max fitness: 25
# generation 55 Max fitness: 24
# generation 56 Max fitness: 22
# generation 57 Max fitness: 25
# generation 58 Max fitness: 24
# generation 59 Max fitness: 25
# generation 60 Max fitness: 23
# generation 61 Max fitness: 24
# generation 62 Max fitness: 25
# generation 63 Max fitness: 23
# generation 64 Max fitness: 24
# generation 65 Max fitness: 26
# generation 66 Max fitness: 26
# generation 67 Max fitness: 26
# generation 68 Max fitness: 26
# generation 69 Max fitness: 26
# generation 70 Max fitness: 26
# generation 71 Max fitness: 26
# generation 72 Max fitness: 26
# generation 73 Max fitness: 26
# generation 74 Max fitness: 25
# generation 75 Max fitness: 27
# generation 76 Max fitness: 27
# generation 77 Max fitness: 27
# generation 78 Max fitness: 26
# generation 79 Max fitness: 26
# generation 80 Max fitness: 26
# generation 81 Max fitness: 27
# generation 82 Max fitness: 26
# generation 83 Max fitness: 26
# generation 84 Max fitness: 27
# generation 85 Max fitness: 27
# generation 86 Max fitness: 26
# generation 87 Max fitness: 25
# generation 88 Max fitness: 25
# generation 89 Max fitness: 26
# generation 90 Max fitness: 26
# generation 91 Max fitness: 26
# generation 92 Max fitness: 26
# generation 93 Max fitness: 27
# generation 94 Max fitness: 26
# generation 95 Max fitness: 26
# generation 96 Max fitness: 26
# generation 97 Max fitness: 26
# generation 98 Max fitness: 26
# generation 99 Max fitness: 26
# generation 100 Max fitness: 26
# generation 101 Max fitness: 26
# generation 102 Max fitness: 25
# generation 103 Max fitness: 26
# generation 104 Max fitness: 27
# generation 105 Max fitness: 25
# generation 106 Max fitness: 25
# generation 107 Max fitness: 25
# generation 108 Max fitness: 25
# generation 109 Max fitness: 26
# generation 110 Max fitness: 25
# generation 111 Max fitness: 26
# generation 112 Max fitness: 25
# generation 113 Max fitness: 25
# generation 114 Max fitness: 25
# generation 115 Max fitness: 25
# generation 116 Max fitness: 26
# generation 117 Max fitness: 26
# generation 118 Max fitness: 26
# generation 119 Max fitness: 26
# generation 120 Max fitness: 27
# generation 121 Max fitness: 25
# generation 122 Max fitness: 26
# generation 123 Max fitness: 25
# generation 124 Max fitness: 25
# generation 125 Max fitness: 24
# generation 126 Max fitness: 24
# generation 127 Max fitness: 22
# generation 128 Max fitness: 25
# generation 129 Max fitness: 23
# generation 130 Max fitness: 24
# generation 131 Max fitness: 25
# generation 132 Max fitness: 23
# generation 133 Max fitness: 23
# generation 134 Max fitness: 25
# generation 135 Max fitness: 25
# generation 136 Max fitness: 25
# generation 137 Max fitness: 24
# generation 138 Max fitness: 25
# generation 139 Max fitness: 25
# generation 140 Max fitness: 24
# generation 141 Max fitness: 25
# generation 142 Max fitness: 25
# generation 143 Max fitness: 24
# generation 144 Max fitness: 25
# generation 145 Max fitness: 24
# generation 146 Max fitness: 24
# generation 147 Max fitness: 25
# generation 148 Max fitness: 25
# generation 149 Max fitness: 25
# generation 150 Max fitness: 23
# generation 151 Max fitness: 24
# generation 152 Max fitness: 24
# generation 153 Max fitness: 24
# generation 154 Max fitness: 25
# generation 155 Max fitness: 22
# generation 156 Max fitness: 23
# generation 157 Max fitness: 22
# generation 158 Max fitness: 24
# generation 159 Max fitness: 25
# generation 160 Max fitness: 25
# generation 161 Max fitness: 25
# generation 162 Max fitness: 25
# generation 163 Max fitness: 27
# generation 164 Max fitness: 25
# generation 165 Max fitness: 25
# generation 166 Max fitness: 26
# generation 167 Max fitness: 26
# generation 168 Max fitness: 26
# generation 169 Max fitness: 27
# generation 170 Max fitness: 26
# generation 171 Max fitness: 26
# generation 172 Max fitness: 23
# generation 173 Max fitness: 26
# generation 174 Max fitness: 23
# generation 175 Max fitness: 25
# generation 176 Max fitness: 26
# generation 177 Max fitness: 26
# generation 178 Max fitness: 25
# generation 179 Max fitness: 25
# generation 180 Max fitness: 25
# generation 181 Max fitness: 24
# generation 182 Max fitness: 25
# generation 183 Max fitness: 24
# generation 184 Max fitness: 24
# generation 185 Max fitness: 24
# generation 186 Max fitness: 24
# generation 187 Max fitness: 25
# generation 188 Max fitness: 26
# generation 189 Max fitness: 27
# generation 190 Max fitness: 27
# generation 191 Max fitness: 26
# generation 192 Max fitness: 27
# generation 193 Max fitness: 25
# generation 194 Max fitness: 25
# generation 195 Max fitness: 24
# generation 196 Max fitness: 23
# generation 197 Max fitness: 25
# generation 198 Max fitness: 24
# generation 199 Max fitness: 25
# generation 200 Max fitness: 25
# generation 201 Max fitness: 23
# generation 202 Max fitness: 24
# generation 203 Max fitness: 23
# generation 204 Max fitness: 24
# generation 205 Max fitness: 24
# generation 206 Max fitness: 23
# generation 207 Max fitness: 23
# generation 208 Max fitness: 24
# generation 209 Max fitness: 25
# generation 210 Max fitness: 25
# generation 211 Max fitness: 25
# Parents::
# Generation: 211
# Fitness: 25
# [8, 4, 6, 2, 3, 1, 7, 5]
# ▧ ☐ ▧ ☐ ▧ ♛ ▧ ☐
# ☐ ▧ ☐ ♛ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ♛ ☐ ▧ ☐
# ☐ ♛ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ☐ ▧ ♛
# ☐ ▧ ♛ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ☐ ♛ ☐
# ♛ ▧ ☐ ▧ ☐ ▧ ☐ ▧
#
# Generation: 211
# Fitness: 25
# [8, 4, 6, 2, 3, 1, 7, 5]
# ▧ ☐ ▧ ☐ ▧ ♛ ▧ ☐
# ☐ ▧ ☐ ♛ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ♛ ☐ ▧ ☐
# ☐ ♛ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ☐ ▧ ♛
# ☐ ▧ ♛ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ☐ ♛ ☐
# ♛ ▧ ☐ ▧ ☐ ▧ ☐ ▧
#
# Solution state:
# Generation: 212
# Fitness: 28
# [2, 4, 6, 8, 3, 1, 7, 5]
# ▧ ☐ ▧ ☐ ▧ ♛ ▧ ☐
# ♛ ▧ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ♛ ☐ ▧ ☐
# ☐ ♛ ☐ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ☐ ▧ ♛
# ☐ ▧ ♛ ▧ ☐ ▧ ☐ ▧
# ▧ ☐ ▧ ☐ ▧ ☐ ♛ ☐
# ☐ ▧ ☐ ♛ ☐ ▧ ☐ ▧
